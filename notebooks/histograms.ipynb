# %%
import plotly.plotly as py
import plotly.tools as tls
from plotly.graph_objs import *
import numpy as np
fig = tls.get_subplots(1,2)
fig
# Out:
# {'data': [],
#  'layout': {'xaxis1': {'anchor': 'y1', 'domain': [0.0, 0.45]},
#   'xaxis2': {'anchor': 'y2', 'domain': [0.55, 1.0]},
#   'yaxis1': {'anchor': 'x1', 'domain': [0.0, 1.0]},
#   'yaxis2': {'anchor': 'x2', 'domain': [0.0, 1.0]}}}

# %%
py.sign_in('pythonapi', 'ubpiol2cve')
x=np.random.randn(1000)
y=np.random.randn(1000)
fig['data'] = Data([Histogram(x=x, xaxis='x1', yaxis='y1'), Histogram(y=y, orientation='h', xaxis='x2', yaxis='y2')])
py.iplot(fig, filename='iss-histogram')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~PythonAPI/162" height="525" width="100%"></iframe>

# %%
help(Histogram)
# Out:
# Help on class Histogram in module plotly.graph_objs.graph_objs:
#
# class Histogram(PlotlyTrace)
#  |  A dictionary-like object for representing a histogram plot in plotly.
#  |
#  |      Example:
#  |          # make a histogram along xaxis...
#  |          py.plot([Histogram(x=[1,1,2,3,2,3,3,3,4,4,5,1,3,4])])
#  |
#  |          # make a histogram along yaxis...
#  |          py.plot([Histogram(y=[1,1,2,3,2,3,3,3,4,4,5,1,3,4])])
#  |
#  |
#  |  Quick method reference:
#  |
#  |      Histogram.update(dict1, **dict2)
#  |      Histogram.strip_style()
#  |      Histogram.get_data()
#  |      Histogram.to_graph_objs()
#  |      Histogram.validate()
#  |      Histogram.force_clean()
#  |
#  |  Valid keys:
#  |
#  |      x [required=True] (value=array-like of numbers, strings, datetimes):
#  |          The x data that is binned and plotted as bars along the x-axis.
#  |
#  |      y [required=True] (value=array-like of numbers, strings, datetimes):
# ...

# %%
fig['data'] = Data([Trace(type='histogramx', x=x, xaxis='x1', yaxis='y1'), Trace(type='histogramy', y=y, xaxis='x2', yaxis='y2')])
py.iplot(fig, filename='iss-histogram-old')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~PythonAPI/163" height="525" width="100%"></iframe>
